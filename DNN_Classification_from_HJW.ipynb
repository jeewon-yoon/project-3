# %%
seed = 1000
GPU = 1
num_workers = 4

# %%
import os
import random
import itertools
from decimal import Decimal
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from datetime import datetime as dt

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
from torch.optim import lr_scheduler

# %%
from sklearn.model_selection import KFold

# %%
sns.set(style="whitegrid", palette="muted", color_codes=True, font_scale=1.25)

# %%
torch.cuda.set_device(GPU)
print('Available devices:', torch.cuda.device_count())
print('Current cuda device:', torch.cuda.current_device())
print(torch.cuda.get_device_name(GPU))
# Out:
# Available devices: 8
# Current cuda device: 1
# GeForce RTX 2080 Ti

# %%
def seed_everything(seed=seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_everything(seed)

# %%
month = '0{}'.format(dt.now().month) if dt.now().month < 10 else str(dt.now().month)
day = '0{}'.format(dt.now().day) if dt.now().day < 10 else str(dt.now().day)
hour = '0{}'.format(dt.now().hour) if dt.now().hour < 10 else str(dt.now().hour)
minute = '0{}'.format(dt.now().minute) if dt.now().minute < 10 else str(dt.now().minute)
sec = '0{}'.format(dt.now().second) if dt.now().second < 10 else str(dt.now().second)

# %%
save_path = "/users/hjw/data/ABCD/DNN/"
output_folder = save_path + "{}{}{}_{}{}{}".format(21, month, day, hour, minute, sec)
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
print(output_folder)
# Out:
# /users/hjw/data/ABCD/DNN/210404_122020

# %%
data = np.load("/users/hjw/data/ABCD/npz_files/MDD_binary_without_NONE.npz", 
               allow_pickle=True)
X = stats.zscore(data["X"], axis=1)
y = data["y"].reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (1356, 46360) (1356, 1)

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
train_folds_idx = []
test_folds_idx = []
for train_idx, test_idx in kf.split(X):
    train_folds_idx.append(train_idx)
    test_folds_idx.append(test_idx)

# %%
epochs = 500
batch_size = 128
learning_rate = 1e-03
optimizer_name = 'nag'
act_func_name = "prelu"

mode = "max"
patience = 5
factor = 0.25
min_lr = 1e-15

momentum = 0.90
l1_param = None
l2_param = 1e-02
dropout_rate = 0.8

n_classes = 1
input_dim = X.shape[-1]
output_dim = n_classes

outer_n_splits = len(train_folds_idx)
inner_n_splits = outer_n_splits - 1

# %%
n_hidden = [128, 128]
beta_lr = [1e-03, 1e-02]
max_beta = [5e-02, 5e-01]
wsc_flag = [1, 1]
num_sparsity_layers = wsc_flag.count(1)
hsp_cand_1 = [0.95, 0.9, 0.8]
hsp_cand_2 = [0.8, 0.5, 0.3]
indices = [i + 1 for i, x in enumerate(wsc_flag) if x == 1]
hsp_cand_list = list(itertools.product(hsp_cand_1, hsp_cand_2))
hsp_cand_list = [list(i) for i in hsp_cand_list]
hsp_cand = [hsp_cand_1, hsp_cand_2]

# %%
f = open(output_folder + "/parameters.txt", 'w')
f.write('Optimizer : ' + str(optimizer_name) + '\n')
f.write('Activation function : ' + str(act_func_name) + '\n')
f.write('Epochs : ' + str(epochs) + '\n')
f.write('Batch size : ' + str(batch_size) + '\n')
f.write('Learning rate : ' + str(learning_rate) + '\n')
f.write('Patience : ' + str(patience) + '\n')
f.write('Factor : ' + str(factor) + '\n')
f.write('Minimum LR : ' + str(min_lr) + '\n')
f.write('L2_reg : ' + str(l2_param) + '\n')
f.write('Number of hidden layer : ' + str(len(n_hidden)) + '\n')
f.write('Number of hidden node : ' + str(n_hidden) + '\n')
f.write('HSP candidate : ' + str(hsp_cand) + '\n')
f.write('Beta learning rate : ' + str(beta_lr) + '\n')
f.write('Max beta : ' + str(max_beta) + '\n')
f.write('Dropout rate : ' + str(dropout_rate) + '\n')
f.close()

# %%
# Training dataset
class train_dataset(Dataset): 
    def __init__(self, X_train, y_train):
        self.X_train = X_train
        self.y_train = y_train
        
    def __len__(self):
        return len(self.X_train)
    
    def __getitem__(self, idx): 
        X_train = torch.from_numpy(self.X_train[idx]).type(torch.FloatTensor)
        y_train = torch.from_numpy(self.y_train[idx]).type(torch.FloatTensor)

        return X_train, y_train

# %%
# Test dataset
class test_dataset(Dataset): 
    def __init__(self, X_test, y_test):
        self.X_test = X_test
        self.y_test = y_test
        
    def __len__(self):
        return len(self.X_test)
    
    def __getitem__(self, idx): 
        X_test = torch.from_numpy(self.X_test[idx]).type(torch.FloatTensor)
        y_test = torch.from_numpy(self.y_test[idx]).type(torch.FloatTensor)
        
        return X_test, y_test

# %%
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.hidden_1 = nn.Linear(input_dim, n_hidden[0])
        self.batch_norm_1 = nn.BatchNorm1d(n_hidden[0])
        self.hidden_2 = nn.Linear(n_hidden[0], n_hidden[1])
        self.batch_norm_2 = nn.BatchNorm1d(n_hidden[1])
        self.output_layer = nn.Linear(n_hidden[1], output_dim)
        self.act_func = get_activation_function(act_func_name)
        self.dropout = nn.Dropout(p=dropout_rate)
        self.weights_init()
    
    def forward(self, x):
        x = self.hidden_1(x)
        x = self.batch_norm_1(x)
        x = self.act_func(x)
        x = self.dropout(x)
        x = self.hidden_2(x)
        x = self.batch_norm_2(x)
        x = self.act_func(x)
        x = self.dropout(x)
        out = self.output_layer(x)
        return out

    def weights_init(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                # He initialization for ReLU
                nn.init.kaiming_normal_(m.weight)
                # Bias initialization
                nn.init.normal_(m.bias, std=0.01)

# %%
def get_optimizer(model, opt_name):
    lower_opt_name = opt_name.lower()
    if lower_opt_name == 'momentum':
        return optim.SGD(model.parameters(), lr=learning_rate, 
                         momentum=momentum, weight_decay=l2_param)
    elif lower_opt_name == 'nag':
        return optim.SGD(model.parameters(), lr=learning_rate, 
                         momentum=momentum, weight_decay=l2_param, nesterov=True)
    elif lower_opt_name == 'adam':
        return optim.Adam(model.parameters(), lr=learning_rate, 
                          weight_decay=l2_param)
    else:
        sys.exit("Illegal arguement for optimizer type")

# %%
def get_activation_function(act_func_name):
    act_func_name = act_func_name.lower()
    if act_func_name == 'relu':
        return nn.ReLU()
    elif act_func_name == 'prelu':
        return nn.PReLU()
    elif act_func_name == 'elu':
        return nn.ELU()
    elif act_func_name == 'silu':
        return nn.SiLU()
    elif act_func_name == 'leakyrelu':
        return nn.LeakyReLU()
    elif act_func_name == 'tanh':
        return nn.Tanh()
    else:
        sys.exit("Illegal arguement for activation function type")

# %%
def init_hsp():
    hsp_val = np.zeros(num_sparsity_layers)
    beta_val = hsp_val.copy()
    hsp_list = np.zeros((num_sparsity_layers, epochs))
    beta_list = np.zeros((num_sparsity_layers, epochs))
    
    return hsp_val, beta_val, hsp_list, beta_list

# %%
# Weight sparsity control with Hoyer's sparsness (Layer wise)
def calc_hsp(w, beta, max_beta, beta_lr, tg_hsp):
    
    # Get value of weight
    [dim, n_nodes] = w.shape
    num_elements = dim * n_nodes
    norm_ratio = torch.norm(w, 1) / torch.norm(w, 2)

    # Calculate hoyer's sparsity level
    num = np.sqrt(num_elements) - norm_ratio.item()
    den = np.sqrt(num_elements) - 1
    hsp = num / den

    # Update beta
    beta = beta + beta_lr * np.sign(tg_hsp - hsp)
    
    # Trim value
    beta = 0.0 if beta < 0.0 else beta
    beta = max_beta if beta > max_beta else beta

    return [hsp, beta]

# %%
def l1_penalty(model, epoch, hsp_val, beta_val, hsp_list, beta_list, tg_hsp):
    l1_reg = None
    l1_val = 0
    layer_idx = 0
    wsc_idx = 0

    for name, param in model.named_parameters():
        if "hidden"  in name and "weight" in name:
            temp_w = param
            if wsc_flag[layer_idx] != 0:
                hsp_val[wsc_idx], beta_val[wsc_idx] = calc_hsp(
                    temp_w, beta_val[wsc_idx], max_beta[wsc_idx], 
                    beta_lr[wsc_idx], tg_hsp[wsc_idx]
                )
                hsp_list[wsc_idx, epoch - 1] = hsp_val[wsc_idx]
                beta_list[wsc_idx, epoch - 1] = beta_val[wsc_idx]
                layer_reg = torch.norm(temp_w, 1) * beta_val[wsc_idx]
                wsc_idx += 1
            else:
                layer_reg = torch.norm(temp_w, 1) * l1_param
            l1_val += torch.norm(temp_w, 1)
            
            if l1_reg is None:
                l1_reg = layer_reg
            else:
                l1_reg = l1_reg + layer_reg
            layer_idx += 1
        
    return l1_reg, l1_val

# %%
def train(model, epoch, train_loader, optimizer, criterion,
          hsp_val, beta_val, hsp_list, beta_list, tg_hsp):    
    model.train()
    train_loss = 0
    total = 0
    train_acc = 0
    correct = 0
    
    for batch_idx, (input, target) in enumerate(train_loader):
        optimizer.zero_grad()
        input, target = input.to(DEVICE), target.to(DEVICE)
        output = model(input)
        loss = criterion(output, target)
        l1_term, l1_val = l1_penalty(
            model, epoch, hsp_val, beta_val, hsp_list, beta_list, tg_hsp)
        cost = loss + l1_term
        train_loss += loss
        cost.backward()
        optimizer.step()
        total += output.size(0)
        pred = (output.data > 0.5).float()
        correct += (pred == target).sum().item()

    train_loss /= total
    train_acc = 100 * correct / total
    return train_loss, train_acc, l1_val

# %%
def test(model, epoch, test_loader, criterion):
    model.eval()
    test_loss = 0
    test_acc = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for input, target in test_loader:
            input, target = input.to(DEVICE), target.to(DEVICE)
            output = model(input)
            loss = criterion(output, target)
            test_loss += loss.item()
            pred = (output.data > 0.5).float()
            total += output.size(0)
            correct += (pred == target).sum().item()
            
    test_loss /= total
    test_acc = 100 * correct / total
    return test_loss, test_acc

# %%
def plot_learning_curves(save_dir, epoch, 
                         plot_train_loss, plot_test_loss, 
                         plot_train_acc, plot_test_acc, 
                         plot_lr_list, plot_l1_list,
                         plot_hsp_list, plot_beta_list, tg_hsp):
    
    sns.set(style="darkgrid", font_scale=1.5)
    fig, ax = plt.subplots(3, 2, figsize=(14, 11))
    
    last_epoch = epoch

    ax = ax.flat
    lw = 2.5
    ax[0].plot(plot_train_loss[:last_epoch], label='train loss', lw=lw)
    ax[0].plot(plot_test_loss[:last_epoch], label='test loss', lw=lw)
    ax[0].set_title("Loss plot")
    ax[0].legend()
    
    ax[1].plot(plot_train_acc[:last_epoch], label='train acc', lw=lw)
    ax[1].plot(plot_test_acc[:last_epoch], label='test acc', lw=lw)
    ax[1].legend()
    ax[1].set_title("Accuracy plot ($acc$={:.2f}%)"
                       .format(plot_test_acc[-1]))
    
    ax[2].plot(plot_lr_list[:last_epoch], label='learning rate', lw=lw)
    ax[2].legend()
    ax[2].set_title("Learning rate plot")
    
    ax[3].plot(plot_l1_list[:last_epoch], label='learning rate', lw=lw)
    ax[3].legend()
    ax[3].set_title("L1 term plot")
    
    plot_hsp_list = np.array(plot_hsp_list).T
    plot_beta_list = np.array(plot_beta_list).T
    
    for idx, n_layer in enumerate(indices):
        if wsc_flag[idx] == 0:
            continue;
        ax[4].plot(plot_hsp_list[idx], label='layer{}'.format(n_layer), lw=lw)
        ax[5].plot(plot_beta_list[idx], 
                   label='layer{}'.format(n_layer), lw=lw)
        ax[4].legend(); ax[5].legend()
        ax[4].set_title("HSP plot [{:.3f}/{:.3f}]".format(plot_hsp_list[0, -1], tg_hsp[0]))
        ax[5].set_title("Beta plot")

    fig.tight_layout()
    fig.savefig("{}/Learning_curves.png".format(save_dir))
    plt.close(fig)

# %%
def run_fold(n_outer_cv=0, output_folder=output_folder):
    
    # Outer CV
    n_outer_cv = n_outer_cv
    output_folder = output_folder
    
    print("===================================== Outer Fold [{}/{}] =====================================".
          format(n_outer_cv + 1, outer_n_splits))
    outer_save_dir = "{}/Outer_fold_{}".format(output_folder, n_outer_cv+1)
    os.makedirs(outer_save_dir, exist_ok=True)
    outer_train_idx = train_folds_idx[n_outer_cv]
    outer_test_idx = test_folds_idx[n_outer_cv]

    # Assign train-valid dataset
    print("======================================== Test Phase =========================================")
    X_train, y_train = X[outer_train_idx], y[outer_train_idx]
    X_test, y_test = X[outer_test_idx], y[outer_test_idx]

    outer_train_dataset = train_dataset(X_train, y_train)
    outer_test_dataset = test_dataset(X_test, y_test)
    outer_train_loader = DataLoader(outer_train_dataset, batch_size=batch_size, 
                                    shuffle=True, num_workers=num_workers, drop_last=True)
    outer_test_loader = DataLoader(outer_test_dataset, batch_size=batch_size, 
                                    shuffle=True, num_workers=num_workers, drop_last=True)
    # Assign model 
    model = DNN().to(DEVICE)
    optimizer = get_optimizer(model, optimizer_name)
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode=mode, patience=patience, 
                                               factor=factor, min_lr=min_lr)
    criterion = nn.BCEWithLogitsLoss(reduction='mean')
    
    # list to save learning parameters
    outer_train_loss = []
    outer_test_loss = []
    outer_train_acc = []
    outer_test_acc = []
    outer_lr_list = []
    outer_hsp_list = []
    outer_beta_list = []
    outer_l1_list = []
    
    hsp_val, beta_val, hsp_list, beta_list = init_hsp()

    for epoch in range(1, epochs+1):
        train_loss, train_acc, l1_val = train(
            model, epoch, outer_train_loader, optimizer, criterion, 
            hsp_val, beta_val, hsp_list, beta_list, tg_hsp)
        test_loss, test_acc = test(
            model, epoch, outer_test_loader, criterion)
        
        scheduler.step(hsp_val[0])
        lr = optimizer.param_groups[0]['lr']
        
        outer_train_loss.append(train_loss)
        outer_test_loss.append(test_loss)
        outer_train_acc.append(train_acc)
        outer_test_acc.append(test_acc)
        outer_lr_list.append(lr)
        outer_hsp_list.append(list(hsp_val))
        outer_beta_list.append(list(beta_val))
        outer_l1_list.append(l1_val)
        
        if epoch % 1 == 0:
            print("Epoch: [{:d}/{:d}], Train acc: {:.2f}, Test acc: {:.2f}".
                  format(epoch, epochs, train_acc, test_acc), end=", ")
            print("Train loss: {:.4f}, Test loss: {:.4f}".
                  format(train_loss, test_loss))
            for i in range(len(n_hidden)):
                if wsc_flag[i] != 0:
                    print("Layer {:d}: [{:.4f}/{:.4f}]".
                          format(i+1, hsp_val[i], tg_hsp[i]), end=" ")
            print("Current learning rate: {:.2e}".format(Decimal(str(lr))))

            plot_learning_curves(
                outer_save_dir, epochs, 
                outer_train_loss, outer_test_loss, 
                outer_train_acc, outer_test_acc, 
                outer_lr_list, outer_l1_list,
                outer_hsp_list, outer_beta_list, tg_hsp
            )
            if n_outer_cv == 0:
                torch.save(model.state_dict(), outer_save_dir + "/model.pt")
            
    print("Outer Fold [{}/{}], selected HSP: {}".
          format(n_outer_cv+1, outer_n_splits, tg_hsp))
    print("Test accuracy: {:.2f}\n".format(test_acc))
    return train_acc, test_acc

# %%
hsp_loop_results = []

for tg_hsp in hsp_cand_list:
    hsp_output_folder = output_folder + "/" + str(tg_hsp)
    print(hsp_output_folder)
    
    folds_acc = []
    
    for i in range(outer_n_splits):
        fold_train_acc, fold_test_acc = run_fold(
            n_outer_cv=i, output_folder=hsp_output_folder
        )
        folds_acc.append([fold_train_acc, fold_test_acc])
        
    acc_df = pd.DataFrame(folds_acc, columns=["train", "test"])
    acc_df.to_csv("{}/acc_results.csv".format(hsp_output_folder))
    print("Test accuracy in {}: {:.3f}".format(tg_hsp, acc_df["test"].mean()))

    # draw barplot
    sns.set(style="whitegrid", font_scale=1.75)
    fig, ax = plt.subplots(figsize=(14, 6))
    sns.barplot(y="test", x=acc_df.index+1, data=acc_df, ax=ax, palette="deep")
    ax.set_xlabel("Fold")
    ax.set_ylabel("Accuracy")
    ax.set_title("Leave-one-site-out CV results (avg test acc: {:.3f})"
                 .format(acc_df["test"].mean()))
    fig.savefig("{}/bar_graph.png".format(hsp_output_folder))
    
    hsp_loop_results.append([tg_hsp, folds_acc])
# Out:
# /users/hjw/data/ABCD/DNN/210404_122020/[0.95, 0.8]
# ===================================== Outer Fold [1/5] =====================================
# ======================================== Test Phase =========================================
# Epoch: [1/500], Train acc: 50.59, Test acc: 47.66, Train loss: 0.0092, Test loss: 0.0065
# Layer 1: [0.2074/0.9500] Layer 2: [0.2048/0.8000] Current learning rate: 1.00e-3
# Epoch: [2/500], Train acc: 52.54, Test acc: 49.22, Train loss: 0.0085, Test loss: 0.0066
# Layer 1: [0.2332/0.9500] Layer 2: [0.2184/0.8000] Current learning rate: 1.00e-3
# Epoch: [3/500], Train acc: 53.42, Test acc: 52.34, Train loss: 0.0082, Test loss: 0.0060
# Layer 1: [0.2875/0.9500] Layer 2: [0.2472/0.8000] Current learning rate: 1.00e-3
# Epoch: [4/500], Train acc: 58.30, Test acc: 54.69, Train loss: 0.0073, Test loss: 0.0053
# Layer 1: [0.3717/0.9500] Layer 2: [0.2934/0.8000] Current learning rate: 1.00e-3
# Epoch: [5/500], Train acc: 58.50, Test acc: 58.98, Train loss: 0.0074, Test loss: 0.0053
# Layer 1: [0.4789/0.9500] Layer 2: [0.3568/0.8000] Current learning rate: 1.00e-3
# Epoch: [6/500], Train acc: 56.05, Test acc: 53.52, Train loss: 0.0072, Test loss: 0.0056
# Layer 1: [0.5872/0.9500] Layer 2: [0.4354/0.8000] Current learning rate: 1.00e-3
# Epoch: [7/500], Train acc: 58.89, Test acc: 57.42, Train loss: 0.0067, Test loss: 0.0055
# Layer 1: [0.6481/0.9500] Layer 2: [0.5234/0.8000] Current learning rate: 1.00e-3
# Epoch: [8/500], Train acc: 55.27, Test acc: 52.34, Train loss: 0.0071, Test loss: 0.0054
# Layer 1: [0.6033/0.9500] Layer 2: [0.6071/0.8000] Current learning rate: 1.00e-3
# Epoch: [9/500], Train acc: 53.52, Test acc: 51.17, Train loss: 0.0074, Test loss: 0.0057
# Layer 1: [0.4856/0.9500] Layer 2: [0.6802/0.8000] Current learning rate: 1.00e-3
# Epoch: [10/500], Train acc: 52.44, Test acc: 48.83, Train loss: 0.0074, Test loss: 0.0053
# Layer 1: [0.3994/0.9500] Layer 2: [0.7432/0.8000] Current learning rate: 1.00e-3
# Epoch: [11/500], Train acc: 52.83, Test acc: 48.05, Train loss: 0.0075, Test loss: 0.0053
# Layer 1: [0.3517/0.9500] Layer 2: [0.7781/0.8000] Current learning rate: 1.00e-3
# Epoch: [12/500], Train acc: 49.51, Test acc: 48.83, Train loss: 0.0077, Test loss: 0.0054
# Layer 1: [0.3379/0.9500] Layer 2: [0.7731/0.8000] Current learning rate: 1.00e-3
# Epoch: [13/500], Train acc: 50.78, Test acc: 50.39, Train loss: 0.0073, Test loss: 0.0054
# Layer 1: [0.3143/0.9500] Layer 2: [0.6924/0.8000] Current learning rate: 2.50e-4
# Epoch: [14/500], Train acc: 53.81, Test acc: 48.83, Train loss: 0.0072, Test loss: 0.0054
# Layer 1: [0.4323/0.9500] Layer 2: [0.8005/0.8000] Current learning rate: 2.50e-4
# Epoch: [15/500], Train acc: 52.54, Test acc: 48.05, Train loss: 0.0075, Test loss: 0.0054
# Layer 1: [0.3905/0.9500] Layer 2: [0.7608/0.8000] Current learning rate: 2.50e-4
# Epoch: [16/500], Train acc: 51.27, Test acc: 49.22, Train loss: 0.0074, Test loss: 0.0054
# Layer 1: [0.3655/0.9500] Layer 2: [0.7246/0.8000] Current learning rate: 2.50e-4
# Epoch: [17/500], Train acc: 52.54, Test acc: 48.05, Train loss: 0.0073, Test loss: 0.0057
# Layer 1: [0.3683/0.9500] Layer 2: [0.6877/0.8000] Current learning rate: 2.50e-4
# Epoch: [18/500], Train acc: 53.71, Test acc: 48.44, Train loss: 0.0074, Test loss: 0.0072
# Layer 1: [0.3731/0.9500] Layer 2: [0.6473/0.8000] Current learning rate: 2.50e-4
# Epoch: [19/500], Train acc: 52.34, Test acc: 48.05, Train loss: 0.0070, Test loss: 0.0056
# Layer 1: [0.3590/0.9500] Layer 2: [0.5982/0.8000] Current learning rate: 6.25e-5
# Epoch: [20/500], Train acc: 55.37, Test acc: 59.38, Train loss: 0.0068, Test loss: 0.0054
# Layer 1: [0.4934/0.9500] Layer 2: [0.7107/0.8000] Current learning rate: 6.25e-5
# Epoch: [21/500], Train acc: 57.03, Test acc: 47.27, Train loss: 0.0064, Test loss: 0.0053
# Layer 1: [0.3961/0.9500] Layer 2: [0.7105/0.8000] Current learning rate: 6.25e-5
# Epoch: [22/500], Train acc: 54.49, Test acc: 48.44, Train loss: 0.0068, Test loss: 0.0061
# Layer 1: [0.3934/0.9500] Layer 2: [0.6726/0.8000] Current learning rate: 6.25e-5
# Epoch: [23/500], Train acc: 56.35, Test acc: 53.12, Train loss: 0.0066, Test loss: 0.0054
# Layer 1: [0.3852/0.9500] Layer 2: [0.6599/0.8000] Current learning rate: 6.25e-5
# Epoch: [24/500], Train acc: 56.64, Test acc: 55.08, Train loss: 0.0067, Test loss: 0.0055
# Layer 1: [0.3819/0.9500] Layer 2: [0.6430/0.8000] Current learning rate: 6.25e-5
# Epoch: [25/500], Train acc: 55.86, Test acc: 50.39, Train loss: 0.0066, Test loss: 0.0062
# Layer 1: [0.3810/0.9500] Layer 2: [0.6294/0.8000] Current learning rate: 1.56e-5
# Epoch: [26/500], Train acc: 57.32, Test acc: 56.25, Train loss: 0.0065, Test loss: 0.0053
# Layer 1: [0.4688/0.9500] Layer 2: [0.6978/0.8000] Current learning rate: 1.56e-5
# Epoch: [27/500], Train acc: 61.13, Test acc: 54.69, Train loss: 0.0057, Test loss: 0.0059
# Layer 1: [0.4962/0.9500] Layer 2: [0.7534/0.8000] Current learning rate: 1.56e-5
# Epoch: [28/500], Train acc: 62.01, Test acc: 53.12, Train loss: 0.0058, Test loss: 0.0054
# Layer 1: [0.4237/0.9500] Layer 2: [0.7673/0.8000] Current learning rate: 1.56e-5
# Epoch: [29/500], Train acc: 60.64, Test acc: 53.12, Train loss: 0.0058, Test loss: 0.0058
# Layer 1: [0.3942/0.9500] Layer 2: [0.7578/0.8000] Current learning rate: 1.56e-5
# Epoch: [30/500], Train acc: 62.89, Test acc: 57.81, Train loss: 0.0058, Test loss: 0.0052
# Layer 1: [0.3908/0.9500] Layer 2: [0.7427/0.8000] Current learning rate: 1.56e-5
# Epoch: [31/500], Train acc: 62.89, Test acc: 55.47, Train loss: 0.0057, Test loss: 0.0062
# Layer 1: [0.3921/0.9500] Layer 2: [0.7373/0.8000] Current learning rate: 3.91e-6
# Epoch: [32/500], Train acc: 65.62, Test acc: 56.25, Train loss: 0.0053, Test loss: 0.0055
# Layer 1: [0.4294/0.9500] Layer 2: [0.7645/0.8000] Current learning rate: 3.91e-6
# Epoch: [33/500], Train acc: 66.41, Test acc: 57.42, Train loss: 0.0050, Test loss: 0.0054
# Layer 1: [0.4787/0.9500] Layer 2: [0.8021/0.8000] Current learning rate: 3.91e-6
# Epoch: [34/500], Train acc: 70.61, Test acc: 60.94, Train loss: 0.0044, Test loss: 0.0053
# Layer 1: [0.5038/0.9500] Layer 2: [0.8281/0.8000] Current learning rate: 3.91e-6
# Epoch: [35/500], Train acc: 76.37, Test acc: 54.69, Train loss: 0.0039, Test loss: 0.0059
# Layer 1: [0.4977/0.9500] Layer 2: [0.8398/0.8000] Current learning rate: 3.91e-6
# Epoch: [36/500], Train acc: 74.02, Test acc: 54.69, Train loss: 0.0039, Test loss: 0.0058
# Layer 1: [0.4653/0.9500] Layer 2: [0.8389/0.8000] Current learning rate: 3.91e-6
# Epoch: [37/500], Train acc: 75.49, Test acc: 51.95, Train loss: 0.0039, Test loss: 0.0061
# Layer 1: [0.4331/0.9500] Layer 2: [0.8290/0.8000] Current learning rate: 9.77e-7
# Epoch: [38/500], Train acc: 75.78, Test acc: 56.64, Train loss: 0.0037, Test loss: 0.0059
# Layer 1: [0.4442/0.9500] Layer 2: [0.8263/0.8000] Current learning rate: 9.77e-7
# Epoch: [39/500], Train acc: 77.64, Test acc: 56.64, Train loss: 0.0034, Test loss: 0.0061
# Layer 1: [0.4810/0.9500] Layer 2: [0.8255/0.8000] Current learning rate: 9.77e-7
# Epoch: [40/500], Train acc: 81.15, Test acc: 55.86, Train loss: 0.0033, Test loss: 0.0063
# Layer 1: [0.5111/0.9500] Layer 2: [0.8209/0.8000] Current learning rate: 9.77e-7
# Epoch: [41/500], Train acc: 81.74, Test acc: 59.38, Train loss: 0.0028, Test loss: 0.0061
# Layer 1: [0.5318/0.9500] Layer 2: [0.8152/0.8000] Current learning rate: 9.77e-7
# Epoch: [42/500], Train acc: 85.45, Test acc: 56.25, Train loss: 0.0024, Test loss: 0.0066
# Layer 1: [0.5445/0.9500] Layer 2: [0.8094/0.8000] Current learning rate: 9.77e-7
# Epoch: [43/500], Train acc: 85.94, Test acc: 56.64, Train loss: 0.0025, Test loss: 0.0067
# Layer 1: [0.5479/0.9500] Layer 2: [0.8040/0.8000] Current learning rate: 2.44e-7
# Epoch: [44/500], Train acc: 89.26, Test acc: 58.20, Train loss: 0.0019, Test loss: 0.0062
# Layer 1: [0.5573/0.9500] Layer 2: [0.8023/0.8000] Current learning rate: 2.44e-7
# Epoch: [45/500], Train acc: 91.70, Test acc: 57.03, Train loss: 0.0018, Test loss: 0.0062
# Layer 1: [0.5794/0.9500] Layer 2: [0.8013/0.8000] Current learning rate: 2.44e-7
# Epoch: [46/500], Train acc: 90.33, Test acc: 55.47, Train loss: 0.0018, Test loss: 0.0065
# Layer 1: [0.6015/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 2.44e-7
# Epoch: [47/500], Train acc: 92.29, Test acc: 57.42, Train loss: 0.0017, Test loss: 0.0066
# Layer 1: [0.6214/0.9500] Layer 2: [0.7996/0.8000] Current learning rate: 2.44e-7
# Epoch: [48/500], Train acc: 93.36, Test acc: 55.08, Train loss: 0.0015, Test loss: 0.0068
# Layer 1: [0.6387/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 2.44e-7
# Epoch: [49/500], Train acc: 92.58, Test acc: 56.64, Train loss: 0.0016, Test loss: 0.0066
# Layer 1: [0.6543/0.9500] Layer 2: [0.8014/0.8000] Current learning rate: 2.44e-7
# Epoch: [50/500], Train acc: 93.65, Test acc: 57.81, Train loss: 0.0015, Test loss: 0.0067
# Layer 1: [0.6657/0.9500] Layer 2: [0.8021/0.8000] Current learning rate: 2.44e-7
# Epoch: [51/500], Train acc: 94.63, Test acc: 57.81, Train loss: 0.0014, Test loss: 0.0066
# Layer 1: [0.6771/0.9500] Layer 2: [0.8019/0.8000] Current learning rate: 2.44e-7
# Epoch: [52/500], Train acc: 93.55, Test acc: 54.69, Train loss: 0.0013, Test loss: 0.0066
# Layer 1: [0.6893/0.9500] Layer 2: [0.8012/0.8000] Current learning rate: 2.44e-7
# Epoch: [53/500], Train acc: 94.53, Test acc: 55.08, Train loss: 0.0014, Test loss: 0.0069
# Layer 1: [0.6960/0.9500] Layer 2: [0.8003/0.8000] Current learning rate: 2.44e-7
# Epoch: [54/500], Train acc: 95.12, Test acc: 56.25, Train loss: 0.0012, Test loss: 0.0067
# Layer 1: [0.7037/0.9500] Layer 2: [0.7995/0.8000] Current learning rate: 2.44e-7
# Epoch: [55/500], Train acc: 94.43, Test acc: 55.47, Train loss: 0.0013, Test loss: 0.0065
# Layer 1: [0.7093/0.9500] Layer 2: [0.7998/0.8000] Current learning rate: 2.44e-7
# Epoch: [56/500], Train acc: 93.36, Test acc: 55.08, Train loss: 0.0013, Test loss: 0.0066
# Layer 1: [0.7116/0.9500] Layer 2: [0.8013/0.8000] Current learning rate: 2.44e-7
# Epoch: [57/500], Train acc: 94.82, Test acc: 56.25, Train loss: 0.0013, Test loss: 0.0069
# Layer 1: [0.7138/0.9500] Layer 2: [0.8023/0.8000] Current learning rate: 2.44e-7
# Epoch: [58/500], Train acc: 94.04, Test acc: 56.25, Train loss: 0.0013, Test loss: 0.0070
# Layer 1: [0.7165/0.9500] Layer 2: [0.8022/0.8000] Current learning rate: 2.44e-7
# Epoch: [59/500], Train acc: 96.29, Test acc: 57.42, Train loss: 0.0012, Test loss: 0.0071
# Layer 1: [0.7160/0.9500] Layer 2: [0.8015/0.8000] Current learning rate: 2.44e-7
# Epoch: [60/500], Train acc: 95.21, Test acc: 55.86, Train loss: 0.0012, Test loss: 0.0069
# Layer 1: [0.7174/0.9500] Layer 2: [0.8007/0.8000] Current learning rate: 2.44e-7
# Epoch: [61/500], Train acc: 95.70, Test acc: 55.47, Train loss: 0.0012, Test loss: 0.0070
# Layer 1: [0.7210/0.9500] Layer 2: [0.7998/0.8000] Current learning rate: 2.44e-7
# Epoch: [62/500], Train acc: 93.55, Test acc: 56.25, Train loss: 0.0013, Test loss: 0.0069
# Layer 1: [0.7189/0.9500] Layer 2: [0.7997/0.8000] Current learning rate: 2.44e-7
# Epoch: [63/500], Train acc: 93.55, Test acc: 56.64, Train loss: 0.0013, Test loss: 0.0075
# Layer 1: [0.7130/0.9500] Layer 2: [0.8009/0.8000] Current learning rate: 2.44e-7
# Epoch: [64/500], Train acc: 95.02, Test acc: 56.25, Train loss: 0.0013, Test loss: 0.0073
# Layer 1: [0.7089/0.9500] Layer 2: [0.8017/0.8000] Current learning rate: 2.44e-7
# Epoch: [65/500], Train acc: 94.24, Test acc: 56.25, Train loss: 0.0013, Test loss: 0.0080
# Layer 1: [0.7041/0.9500] Layer 2: [0.8016/0.8000] Current learning rate: 2.44e-7
# Epoch: [66/500], Train acc: 94.43, Test acc: 57.03, Train loss: 0.0013, Test loss: 0.0070
# Layer 1: [0.7002/0.9500] Layer 2: [0.8009/0.8000] Current learning rate: 2.44e-7
# Epoch: [67/500], Train acc: 93.75, Test acc: 54.69, Train loss: 0.0013, Test loss: 0.0072
# Layer 1: [0.6901/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 6.10e-8
# Epoch: [68/500], Train acc: 94.43, Test acc: 57.42, Train loss: 0.0013, Test loss: 0.0069
# Layer 1: [0.6924/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 6.10e-8
# Epoch: [69/500], Train acc: 95.51, Test acc: 57.42, Train loss: 0.0012, Test loss: 0.0069
# Layer 1: [0.7012/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 6.10e-8
# Epoch: [70/500], Train acc: 95.02, Test acc: 56.64, Train loss: 0.0012, Test loss: 0.0072
# Layer 1: [0.7111/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 6.10e-8
# Epoch: [71/500], Train acc: 95.80, Test acc: 57.81, Train loss: 0.0010, Test loss: 0.0068
# Layer 1: [0.7216/0.9500] Layer 2: [0.8005/0.8000] Current learning rate: 6.10e-8
# Epoch: [72/500], Train acc: 95.90, Test acc: 57.03, Train loss: 0.0011, Test loss: 0.0070
# Layer 1: [0.7317/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 6.10e-8
# Epoch: [73/500], Train acc: 96.48, Test acc: 57.81, Train loss: 0.0010, Test loss: 0.0073
# Layer 1: [0.7409/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 6.10e-8
# Epoch: [74/500], Train acc: 97.66, Test acc: 57.03, Train loss: 0.0010, Test loss: 0.0072
# Layer 1: [0.7496/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 6.10e-8
# Epoch: [75/500], Train acc: 97.46, Test acc: 55.08, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.7579/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 6.10e-8
# Epoch: [76/500], Train acc: 97.66, Test acc: 55.08, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.7656/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 6.10e-8
# Epoch: [77/500], Train acc: 97.46, Test acc: 54.69, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.7719/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 6.10e-8
# Epoch: [78/500], Train acc: 97.27, Test acc: 56.64, Train loss: 0.0009, Test loss: 0.0071
# Layer 1: [0.7781/0.9500] Layer 2: [0.8005/0.8000] Current learning rate: 6.10e-8
# Epoch: [79/500], Train acc: 98.05, Test acc: 57.03, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.7834/0.9500] Layer 2: [0.8003/0.8000] Current learning rate: 6.10e-8
# Epoch: [80/500], Train acc: 97.36, Test acc: 56.25, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.7885/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 6.10e-8
# Epoch: [81/500], Train acc: 97.17, Test acc: 55.08, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.7920/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 6.10e-8
# Epoch: [82/500], Train acc: 97.07, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.7955/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 6.10e-8
# Epoch: [83/500], Train acc: 97.85, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.7993/0.9500] Layer 2: [0.8003/0.8000] Current learning rate: 6.10e-8
# Epoch: [84/500], Train acc: 97.85, Test acc: 57.03, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8028/0.9500] Layer 2: [0.8005/0.8000] Current learning rate: 6.10e-8
# Epoch: [85/500], Train acc: 97.27, Test acc: 53.91, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8054/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 6.10e-8
# Epoch: [86/500], Train acc: 97.17, Test acc: 53.52, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8067/0.9500] Layer 2: [0.8003/0.8000] Current learning rate: 6.10e-8
# Epoch: [87/500], Train acc: 97.66, Test acc: 57.03, Train loss: 0.0009, Test loss: 0.0070
# Layer 1: [0.8077/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 6.10e-8
# Epoch: [88/500], Train acc: 97.95, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8093/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 6.10e-8
# Epoch: [89/500], Train acc: 98.05, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0071
# Layer 1: [0.8113/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 6.10e-8
# Epoch: [90/500], Train acc: 97.36, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8121/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 6.10e-8
# Epoch: [91/500], Train acc: 96.97, Test acc: 57.42, Train loss: 0.0010, Test loss: 0.0071
# Layer 1: [0.8127/0.9500] Layer 2: [0.8006/0.8000] Current learning rate: 6.10e-8
# Epoch: [92/500], Train acc: 97.07, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8134/0.9500] Layer 2: [0.8005/0.8000] Current learning rate: 6.10e-8
# Epoch: [93/500], Train acc: 98.05, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8142/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 6.10e-8
# Epoch: [94/500], Train acc: 96.88, Test acc: 54.69, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8153/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 6.10e-8
# Epoch: [95/500], Train acc: 97.56, Test acc: 55.08, Train loss: 0.0009, Test loss: 0.0071
# Layer 1: [0.8162/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 6.10e-8
# Epoch: [96/500], Train acc: 96.88, Test acc: 54.30, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8166/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 6.10e-8
# Epoch: [97/500], Train acc: 97.46, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8168/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 6.10e-8
# Epoch: [98/500], Train acc: 97.85, Test acc: 54.30, Train loss: 0.0009, Test loss: 0.0071
# Layer 1: [0.8168/0.9500] Layer 2: [0.8005/0.8000] Current learning rate: 6.10e-8
# Epoch: [99/500], Train acc: 97.66, Test acc: 56.25, Train loss: 0.0009, Test loss: 0.0070
# Layer 1: [0.8164/0.9500] Layer 2: [0.8006/0.8000] Current learning rate: 6.10e-8
# Epoch: [100/500], Train acc: 97.56, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8163/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 6.10e-8
# Epoch: [101/500], Train acc: 98.34, Test acc: 54.69, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8169/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 6.10e-8
# Epoch: [102/500], Train acc: 97.75, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0076
# Layer 1: [0.8186/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 6.10e-8
# Epoch: [103/500], Train acc: 97.95, Test acc: 57.03, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8208/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 6.10e-8
# Epoch: [104/500], Train acc: 98.63, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8211/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 6.10e-8
# Epoch: [105/500], Train acc: 97.56, Test acc: 54.69, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8217/0.9500] Layer 2: [0.8005/0.8000] Current learning rate: 6.10e-8
# Epoch: [106/500], Train acc: 98.05, Test acc: 53.52, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8210/0.9500] Layer 2: [0.8006/0.8000] Current learning rate: 6.10e-8
# Epoch: [107/500], Train acc: 98.24, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8213/0.9500] Layer 2: [0.8005/0.8000] Current learning rate: 6.10e-8
# Epoch: [108/500], Train acc: 97.66, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8226/0.9500] Layer 2: [0.8003/0.8000] Current learning rate: 6.10e-8
# Epoch: [109/500], Train acc: 96.19, Test acc: 54.30, Train loss: 0.0010, Test loss: 0.0073
# Layer 1: [0.8223/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 6.10e-8
# Epoch: [110/500], Train acc: 97.66, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8203/0.9500] Layer 2: [0.7999/0.8000] Current learning rate: 6.10e-8
# Epoch: [111/500], Train acc: 97.75, Test acc: 54.30, Train loss: 0.0009, Test loss: 0.0075
# Layer 1: [0.8186/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 6.10e-8
# Epoch: [112/500], Train acc: 97.95, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0075
# Layer 1: [0.8174/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 6.10e-8
# Epoch: [113/500], Train acc: 97.07, Test acc: 57.81, Train loss: 0.0010, Test loss: 0.0072
# Layer 1: [0.8164/0.9500] Layer 2: [0.8006/0.8000] Current learning rate: 6.10e-8
# Epoch: [114/500], Train acc: 98.54, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8152/0.9500] Layer 2: [0.8005/0.8000] Current learning rate: 1.53e-8
# Epoch: [115/500], Train acc: 97.46, Test acc: 56.25, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8164/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 1.53e-8
# Epoch: [116/500], Train acc: 98.14, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0075
# Layer 1: [0.8192/0.9500] Layer 2: [0.8004/0.8000] Current learning rate: 1.53e-8
# Epoch: [117/500], Train acc: 97.07, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8226/0.9500] Layer 2: [0.8003/0.8000] Current learning rate: 1.53e-8
# Epoch: [118/500], Train acc: 97.85, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8261/0.9500] Layer 2: [0.8003/0.8000] Current learning rate: 1.53e-8
# Epoch: [119/500], Train acc: 98.34, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8294/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 1.53e-8
# Epoch: [120/500], Train acc: 98.05, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8325/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [121/500], Train acc: 98.05, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8352/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [122/500], Train acc: 98.34, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8378/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [123/500], Train acc: 98.34, Test acc: 53.91, Train loss: 0.0008, Test loss: 0.0076
# Layer 1: [0.8400/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [124/500], Train acc: 97.85, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8420/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [125/500], Train acc: 99.12, Test acc: 56.25, Train loss: 0.0007, Test loss: 0.0072
# Layer 1: [0.8440/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [126/500], Train acc: 98.34, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8460/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 1.53e-8
# Epoch: [127/500], Train acc: 99.02, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8475/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [128/500], Train acc: 98.05, Test acc: 55.08, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8489/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [129/500], Train acc: 98.14, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8501/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [130/500], Train acc: 98.73, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8512/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [131/500], Train acc: 98.54, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8521/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [132/500], Train acc: 98.63, Test acc: 57.42, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8530/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [133/500], Train acc: 98.05, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8536/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [134/500], Train acc: 98.83, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8541/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [135/500], Train acc: 97.85, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8547/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [136/500], Train acc: 98.05, Test acc: 56.25, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8553/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [137/500], Train acc: 98.44, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8559/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [138/500], Train acc: 98.54, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8565/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [139/500], Train acc: 97.95, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8571/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [140/500], Train acc: 98.14, Test acc: 54.69, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8571/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [141/500], Train acc: 98.24, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8571/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [142/500], Train acc: 97.66, Test acc: 56.64, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8574/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [143/500], Train acc: 98.93, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8579/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [144/500], Train acc: 97.75, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8582/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [145/500], Train acc: 98.44, Test acc: 55.08, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8585/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [146/500], Train acc: 98.34, Test acc: 53.52, Train loss: 0.0009, Test loss: 0.0075
# Layer 1: [0.8589/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [147/500], Train acc: 97.66, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8593/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [148/500], Train acc: 98.34, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8594/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [149/500], Train acc: 98.54, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8595/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [150/500], Train acc: 98.34, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8599/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [151/500], Train acc: 98.44, Test acc: 56.64, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8604/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [152/500], Train acc: 98.83, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8608/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [153/500], Train acc: 98.44, Test acc: 53.91, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8610/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [154/500], Train acc: 98.63, Test acc: 53.91, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8613/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [155/500], Train acc: 98.83, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8616/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [156/500], Train acc: 97.95, Test acc: 57.42, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8618/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [157/500], Train acc: 97.66, Test acc: 57.81, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8620/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [158/500], Train acc: 98.73, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8616/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [159/500], Train acc: 97.85, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8616/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [160/500], Train acc: 98.54, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8620/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [161/500], Train acc: 98.34, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8624/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [162/500], Train acc: 98.73, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8629/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [163/500], Train acc: 97.75, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8632/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [164/500], Train acc: 97.46, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8633/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [165/500], Train acc: 98.14, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0070
# Layer 1: [0.8634/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [166/500], Train acc: 98.83, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8634/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [167/500], Train acc: 99.51, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8636/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [168/500], Train acc: 98.34, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8641/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [169/500], Train acc: 97.95, Test acc: 56.25, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8640/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [170/500], Train acc: 98.44, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8642/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [171/500], Train acc: 98.05, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8645/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [172/500], Train acc: 98.24, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8645/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [173/500], Train acc: 97.85, Test acc: 55.08, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8644/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [174/500], Train acc: 98.54, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0070
# Layer 1: [0.8646/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [175/500], Train acc: 98.05, Test acc: 55.08, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8647/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [176/500], Train acc: 98.54, Test acc: 53.52, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8649/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [177/500], Train acc: 98.14, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8651/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [178/500], Train acc: 98.05, Test acc: 53.91, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8652/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [179/500], Train acc: 98.05, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8649/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [180/500], Train acc: 98.54, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8644/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [181/500], Train acc: 98.63, Test acc: 52.73, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8643/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [182/500], Train acc: 98.14, Test acc: 55.08, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8649/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [183/500], Train acc: 98.63, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8654/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [184/500], Train acc: 97.95, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8657/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [185/500], Train acc: 98.83, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8659/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [186/500], Train acc: 98.54, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8660/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [187/500], Train acc: 98.83, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8663/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [188/500], Train acc: 98.44, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8666/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [189/500], Train acc: 98.24, Test acc: 54.30, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8665/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [190/500], Train acc: 98.63, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8657/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [191/500], Train acc: 98.24, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0076
# Layer 1: [0.8656/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 1.53e-8
# Epoch: [192/500], Train acc: 98.24, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8660/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 1.53e-8
# Epoch: [193/500], Train acc: 98.24, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8665/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [194/500], Train acc: 98.34, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8670/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [195/500], Train acc: 98.73, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8672/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [196/500], Train acc: 98.05, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8672/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [197/500], Train acc: 98.34, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8671/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [198/500], Train acc: 98.73, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8672/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [199/500], Train acc: 98.05, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8674/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 1.53e-8
# Epoch: [200/500], Train acc: 98.73, Test acc: 54.69, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8675/0.9500] Layer 2: [0.8002/0.8000] Current learning rate: 1.53e-8
# Epoch: [201/500], Train acc: 98.05, Test acc: 55.08, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8676/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [202/500], Train acc: 97.85, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0075
# Layer 1: [0.8675/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [203/500], Train acc: 98.34, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8677/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [204/500], Train acc: 98.63, Test acc: 55.08, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8678/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [205/500], Train acc: 98.14, Test acc: 53.12, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8679/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [206/500], Train acc: 98.73, Test acc: 55.08, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8677/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [207/500], Train acc: 98.73, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8675/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [208/500], Train acc: 98.34, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8675/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [209/500], Train acc: 97.85, Test acc: 53.91, Train loss: 0.0009, Test loss: 0.0075
# Layer 1: [0.8676/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [210/500], Train acc: 98.24, Test acc: 53.91, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8679/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [211/500], Train acc: 98.14, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8681/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [212/500], Train acc: 98.24, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8682/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [213/500], Train acc: 98.44, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8686/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [214/500], Train acc: 98.05, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8689/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [215/500], Train acc: 98.34, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8691/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [216/500], Train acc: 98.54, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8693/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [217/500], Train acc: 98.73, Test acc: 55.08, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8695/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [218/500], Train acc: 97.95, Test acc: 54.69, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8697/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [219/500], Train acc: 98.73, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8698/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [220/500], Train acc: 98.54, Test acc: 57.42, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8697/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [221/500], Train acc: 98.34, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8697/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [222/500], Train acc: 98.54, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8699/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [223/500], Train acc: 98.44, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8700/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [224/500], Train acc: 98.83, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8703/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [225/500], Train acc: 98.34, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8708/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [226/500], Train acc: 98.34, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8705/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 1.53e-8
# Epoch: [227/500], Train acc: 97.66, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8700/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [228/500], Train acc: 98.83, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8697/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [229/500], Train acc: 98.34, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8696/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [230/500], Train acc: 98.63, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8693/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 1.53e-8
# Epoch: [231/500], Train acc: 98.34, Test acc: 55.08, Train loss: 0.0009, Test loss: 0.0073
# Layer 1: [0.8695/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [232/500], Train acc: 98.34, Test acc: 55.86, Train loss: 0.0009, Test loss: 0.0072
# Layer 1: [0.8698/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [233/500], Train acc: 98.24, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8706/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [234/500], Train acc: 98.93, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8716/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [235/500], Train acc: 98.44, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8725/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 3.81e-9
# Epoch: [236/500], Train acc: 97.85, Test acc: 55.08, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8733/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 3.81e-9
# Epoch: [237/500], Train acc: 98.73, Test acc: 55.08, Train loss: 0.0007, Test loss: 0.0075
# Layer 1: [0.8740/0.9500] Layer 2: [0.8001/0.8000] Current learning rate: 3.81e-9
# Epoch: [238/500], Train acc: 97.75, Test acc: 56.64, Train loss: 0.0009, Test loss: 0.0071
# Layer 1: [0.8747/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [239/500], Train acc: 97.75, Test acc: 53.91, Train loss: 0.0009, Test loss: 0.0074
# Layer 1: [0.8753/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [240/500], Train acc: 97.85, Test acc: 55.47, Train loss: 0.0009, Test loss: 0.0075
# Layer 1: [0.8757/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [241/500], Train acc: 98.14, Test acc: 53.91, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8761/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [242/500], Train acc: 99.12, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8766/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [243/500], Train acc: 98.14, Test acc: 53.91, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8771/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [244/500], Train acc: 97.75, Test acc: 53.91, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8775/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [245/500], Train acc: 99.12, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8779/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [246/500], Train acc: 97.95, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0076
# Layer 1: [0.8782/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [247/500], Train acc: 98.44, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8785/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [248/500], Train acc: 98.73, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8789/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [249/500], Train acc: 98.34, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8792/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [250/500], Train acc: 98.34, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8796/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [251/500], Train acc: 98.83, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8799/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [252/500], Train acc: 98.34, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8801/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [253/500], Train acc: 98.34, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8803/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [254/500], Train acc: 98.63, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8806/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [255/500], Train acc: 98.14, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8808/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [256/500], Train acc: 98.63, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8810/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [257/500], Train acc: 98.83, Test acc: 55.47, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8812/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [258/500], Train acc: 98.34, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8814/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [259/500], Train acc: 98.93, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8815/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [260/500], Train acc: 98.93, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8817/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [261/500], Train acc: 98.54, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8819/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [262/500], Train acc: 98.73, Test acc: 55.08, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8820/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [263/500], Train acc: 98.83, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8822/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [264/500], Train acc: 98.54, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8823/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [265/500], Train acc: 98.44, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8823/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [266/500], Train acc: 97.95, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0074
# Layer 1: [0.8823/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [267/500], Train acc: 97.95, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8823/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [268/500], Train acc: 98.44, Test acc: 53.91, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8824/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [269/500], Train acc: 98.14, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8825/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [270/500], Train acc: 98.44, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8826/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [271/500], Train acc: 99.12, Test acc: 55.86, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8828/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [272/500], Train acc: 98.34, Test acc: 57.42, Train loss: 0.0008, Test loss: 0.0072
# Layer 1: [0.8829/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [273/500], Train acc: 98.83, Test acc: 54.69, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8830/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [274/500], Train acc: 99.02, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0073
# Layer 1: [0.8831/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [275/500], Train acc: 98.63, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8833/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [276/500], Train acc: 98.44, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0071
# Layer 1: [0.8833/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [277/500], Train acc: 97.66, Test acc: 54.30, Train loss: 0.0008, Test loss: 0.0076
# Layer 1: [0.8833/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [278/500], Train acc: 98.44, Test acc: 55.08, Train loss: 0.0008, Test loss: 0.0075
# Layer 1: [0.8835/0.9500] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# ...
# Epoch: [386/500], Train acc: 98.14, Test acc: 57.81, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8752/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [387/500], Train acc: 97.66, Test acc: 58.98, Train loss: 0.0009, Test loss: 0.0065
# Layer 1: [0.8752/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [388/500], Train acc: 98.44, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8753/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [389/500], Train acc: 97.56, Test acc: 58.20, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8753/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [390/500], Train acc: 98.14, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8753/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [391/500], Train acc: 98.05, Test acc: 57.81, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8752/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [392/500], Train acc: 98.34, Test acc: 58.98, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8752/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [393/500], Train acc: 97.95, Test acc: 58.20, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8752/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [394/500], Train acc: 98.73, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8753/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [395/500], Train acc: 98.54, Test acc: 58.98, Train loss: 0.0009, Test loss: 0.0065
# Layer 1: [0.8754/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [396/500], Train acc: 98.05, Test acc: 58.20, Train loss: 0.0009, Test loss: 0.0065
# Layer 1: [0.8755/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [397/500], Train acc: 98.14, Test acc: 58.59, Train loss: 0.0009, Test loss: 0.0065
# Layer 1: [0.8755/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [398/500], Train acc: 98.44, Test acc: 57.42, Train loss: 0.0008, Test loss: 0.0068
# Layer 1: [0.8756/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [399/500], Train acc: 97.66, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0068
# Layer 1: [0.8757/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [400/500], Train acc: 98.14, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8757/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [401/500], Train acc: 98.34, Test acc: 58.98, Train loss: 0.0008, Test loss: 0.0065
# Layer 1: [0.8757/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [402/500], Train acc: 98.14, Test acc: 58.98, Train loss: 0.0008, Test loss: 0.0064
# Layer 1: [0.8758/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [403/500], Train acc: 98.54, Test acc: 59.38, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8759/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [404/500], Train acc: 98.54, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8760/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [405/500], Train acc: 99.12, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8760/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [406/500], Train acc: 98.24, Test acc: 59.38, Train loss: 0.0008, Test loss: 0.0064
# Layer 1: [0.8761/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [407/500], Train acc: 98.93, Test acc: 58.59, Train loss: 0.0009, Test loss: 0.0068
# Layer 1: [0.8762/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [408/500], Train acc: 98.05, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0064
# Layer 1: [0.8763/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [409/500], Train acc: 97.95, Test acc: 59.38, Train loss: 0.0008, Test loss: 0.0064
# Layer 1: [0.8762/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [410/500], Train acc: 97.66, Test acc: 58.20, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8762/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [411/500], Train acc: 98.54, Test acc: 58.98, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8762/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [412/500], Train acc: 98.93, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8763/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [413/500], Train acc: 98.05, Test acc: 57.03, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8763/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [414/500], Train acc: 98.44, Test acc: 58.98, Train loss: 0.0008, Test loss: 0.0065
# Layer 1: [0.8764/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [415/500], Train acc: 98.54, Test acc: 56.25, Train loss: 0.0008, Test loss: 0.0068
# Layer 1: [0.8764/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [416/500], Train acc: 98.24, Test acc: 58.59, Train loss: 0.0009, Test loss: 0.0065
# Layer 1: [0.8765/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [417/500], Train acc: 97.46, Test acc: 59.38, Train loss: 0.0009, Test loss: 0.0065
# Layer 1: [0.8764/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [418/500], Train acc: 98.54, Test acc: 57.03, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8764/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [419/500], Train acc: 98.44, Test acc: 57.81, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8763/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [420/500], Train acc: 98.14, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0068
# Layer 1: [0.8763/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [421/500], Train acc: 98.24, Test acc: 60.16, Train loss: 0.0009, Test loss: 0.0063
# Layer 1: [0.8764/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [422/500], Train acc: 98.34, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8764/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [423/500], Train acc: 97.27, Test acc: 57.81, Train loss: 0.0009, Test loss: 0.0068
# Layer 1: [0.8765/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [424/500], Train acc: 98.54, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8766/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [425/500], Train acc: 98.83, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0068
# Layer 1: [0.8766/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [426/500], Train acc: 98.34, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8768/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [427/500], Train acc: 98.34, Test acc: 57.81, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8768/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [428/500], Train acc: 97.66, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0068
# Layer 1: [0.8769/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [429/500], Train acc: 98.24, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8768/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [430/500], Train acc: 97.66, Test acc: 57.81, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8768/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [431/500], Train acc: 97.85, Test acc: 58.20, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8768/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [432/500], Train acc: 99.12, Test acc: 59.38, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8767/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [433/500], Train acc: 98.63, Test acc: 57.42, Train loss: 0.0008, Test loss: 0.0068
# Layer 1: [0.8767/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [434/500], Train acc: 98.63, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8769/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [435/500], Train acc: 98.83, Test acc: 60.16, Train loss: 0.0008, Test loss: 0.0065
# Layer 1: [0.8770/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [436/500], Train acc: 98.34, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8771/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [437/500], Train acc: 98.63, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8772/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [438/500], Train acc: 98.54, Test acc: 59.38, Train loss: 0.0009, Test loss: 0.0065
# Layer 1: [0.8773/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [439/500], Train acc: 98.83, Test acc: 59.77, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8773/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [440/500], Train acc: 98.34, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8774/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [441/500], Train acc: 97.85, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0068
# Layer 1: [0.8775/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [442/500], Train acc: 97.56, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8775/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [443/500], Train acc: 98.24, Test acc: 58.59, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8775/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [444/500], Train acc: 97.27, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0064
# Layer 1: [0.8774/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [445/500], Train acc: 98.05, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8774/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [446/500], Train acc: 98.34, Test acc: 57.81, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8775/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [447/500], Train acc: 97.56, Test acc: 58.59, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8775/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [448/500], Train acc: 99.02, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8773/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [449/500], Train acc: 97.85, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8773/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [450/500], Train acc: 98.93, Test acc: 58.20, Train loss: 0.0009, Test loss: 0.0068
# Layer 1: [0.8774/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [451/500], Train acc: 98.44, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0068
# Layer 1: [0.8774/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [452/500], Train acc: 98.34, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8776/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [453/500], Train acc: 98.83, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0068
# Layer 1: [0.8777/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [454/500], Train acc: 98.83, Test acc: 56.64, Train loss: 0.0008, Test loss: 0.0068
# Layer 1: [0.8777/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [455/500], Train acc: 97.46, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0068
# Layer 1: [0.8777/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [456/500], Train acc: 98.63, Test acc: 58.20, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8777/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [457/500], Train acc: 98.05, Test acc: 58.20, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8777/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [458/500], Train acc: 98.63, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8777/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [459/500], Train acc: 97.85, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8778/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [460/500], Train acc: 97.75, Test acc: 59.77, Train loss: 0.0008, Test loss: 0.0064
# Layer 1: [0.8778/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [461/500], Train acc: 98.54, Test acc: 58.98, Train loss: 0.0008, Test loss: 0.0065
# Layer 1: [0.8778/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [462/500], Train acc: 98.54, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0065
# Layer 1: [0.8779/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [463/500], Train acc: 98.63, Test acc: 57.81, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8780/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [464/500], Train acc: 97.85, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8781/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [465/500], Train acc: 98.73, Test acc: 57.03, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8782/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [466/500], Train acc: 98.93, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8783/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [467/500], Train acc: 98.24, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8784/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [468/500], Train acc: 96.97, Test acc: 58.98, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8783/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [469/500], Train acc: 97.85, Test acc: 58.20, Train loss: 0.0008, Test loss: 0.0067
# Layer 1: [0.8781/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [470/500], Train acc: 97.75, Test acc: 58.98, Train loss: 0.0009, Test loss: 0.0066
# Layer 1: [0.8780/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [471/500], Train acc: 98.54, Test acc: 58.98, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8780/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [472/500], Train acc: 98.63, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0063
# Layer 1: [0.8781/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [473/500], Train acc: 97.95, Test acc: 56.25, Train loss: 0.0009, Test loss: 0.0069
# Layer 1: [0.8783/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [474/500], Train acc: 98.24, Test acc: 58.98, Train loss: 0.0008, Test loss: 0.0065
# Layer 1: [0.8783/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [475/500], Train acc: 98.73, Test acc: 58.98, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8785/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [476/500], Train acc: 98.54, Test acc: 58.59, Train loss: 0.0008, Test loss: 0.0066
# Layer 1: [0.8786/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [477/500], Train acc: 98.73, Test acc: 58.98, Train loss: 0.0008, Test loss: 0.0064
# Layer 1: [0.8786/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9
# Epoch: [478/500], Train acc: 98.34, Test acc: 57.42, Train loss: 0.0009, Test loss: 0.0067
# Layer 1: [0.8786/0.9000] Layer 2: [0.8000/0.8000] Current learning rate: 3.81e-9

# %%
results_df = pd.DataFrame(hsp_loop_results, columns=["hsp", "result"])
results_df.head()

# %%
acc_df = pd.DataFrame(folds_acc, columns=["train", "test"])
cv_df = acc_df.reset_index()
cv_df = cv_df.rename(columns={"index": "fold"})
cv_df["fold"] = cv_df["fold"] + 1
cv_df

# %%
sns.set_context("talk"); sns.set_style("white"); sns.set_palette("Pastel1")
fig, ax = plt.subplots()
sns.barplot(x="fold", y="test", data=cv_df, ax=ax)
ax.set_title("5-Fold CV Results from DNN (Acc: {:.2f}%)".format(cv_df.test.mean()), pad=12)
ax.set_ylabel("Accuracy (%)")
ax.set_xlabel("Fold")
